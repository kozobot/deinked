# %% [markdown]
# # Process Raw Data
#
# This takes the raw data in the Model/rawdata folder and splits it along the detected 'line' between images

# %%
from fastai.vision.all import *
from PIL import ImageFilter, Image
import numpy as np
import re

# %% [markdown]
# # Set some processing variables

# %%
training_width, training_height = 480,640 # portrait

# %% [markdown]
# # Set up util functions

# %%
resize = Resize((training_height, training_width), 
                 resamples=(Image.BILINEAR, Image.NEAREST),
                 method=ResizeMethod.Pad,
                 pad_mode=PadMode.Zeros)

# process a single image
def process_image(img):
    # Do the resizing
    resize_img = resize(img, split_idx=1) # Resize the image to match our training.
    
    return resize_img.convert('RGB')

# %%
# compile some regex for future matching
clean_re = re.compile(r'.*_clean\..*')
tattoo_re = re.compile(r'.*_tattoo\..*')

# %% [markdown]
# # Process the images

# %%
# Fetch our files from the rawdata
raw_image_files = get_image_files('./data/rawdata')

# loop over all the images and process them
for raw_image_file in raw_image_files:
    # load the image and process
    print(f"Processing {raw_image_file}")
    pil_image = PILImage.create(raw_image_file)
    resize_img = process_image(pil_image)
    
    # Save the file
    basename = os.path.basename(raw_image_file)
    if clean_re.match(basename):
        resize_img.save("./data/clean/" + re.sub(r'_clean', "", basename))
    elif tattoo_re.match(basename):
        resize_img.save("./data/tattoo/" + re.sub(r'_tattoo', "", basename))
    else: 
        print(f"WARNING: {raw_image_file} does not match clean/tattoo naming convention. Skipping.")
# Out:
# Processing data/rawdata/retouchme-22_clean.jpeg
# Processing data/rawdata/retouchme-31_tattoo.jpeg
# Processing data/rawdata/retouchme-45_tattoo.jpeg
# Processing data/rawdata/retouchme-75_clean.jpeg
# Processing data/rawdata/retouchme-51_clean.jpeg
# Processing data/rawdata/retouchme-76_tattoo.jpeg
# Processing data/rawdata/retouchme-39_clean.jpeg
# Processing data/rawdata/retouchme-78_tattoo.jpeg
# Processing data/rawdata/retouchme-28_tattoo.jpeg
# Processing data/rawdata/laser-removal-5_tattoo.jpeg
# Processing data/rawdata/retouchme-10_clean.jpeg
# Processing data/rawdata/retouchme-15_tattoo.jpeg
# Processing data/rawdata/retouchme-1_tattoo.jpeg
# Processing data/rawdata/laser-removal-16_tattoo.jpeg
# Processing data/rawdata/retouchme-12_clean.jpeg
# Processing data/rawdata/retouchme-77_clean.jpeg
# Processing data/rawdata/laser-removal-13_clean.jpeg
# Processing data/rawdata/retouchme-56_tattoo.jpeg
# Processing data/rawdata/retouchme-34_tattoo.jpeg
# Processing data/rawdata/retouchme-54_tattoo.jpeg
# Processing data/rawdata/retouchme-32_clean.jpeg
# Processing data/rawdata/retouchme-18_tattoo.jpeg
# Processing data/rawdata/laser-removal-3_tattoo.jpeg
# Processing data/rawdata/retouchme-16_tattoo.jpeg
# Processing data/rawdata/retouchme-54_clean.jpeg
# Processing data/rawdata/retouchme-15_clean.jpeg
# Processing data/rawdata/retouchme-19_tattoo.jpeg
# Processing data/rawdata/retouchme-13_clean.jpeg
# Processing data/rawdata/retouchme-67_tattoo.jpeg
# Processing data/rawdata/retouchme-7_tattoo.jpeg
# Processing data/rawdata/laser-removal-11_clean.jpeg
# Processing data/rawdata/laser-removal-13_tattoo.jpeg
# Processing data/rawdata/retouchme-7_clean.jpeg
# Processing data/rawdata/retouchme-38_tattoo.jpeg
# Processing data/rawdata/laser-removal-14_clean.jpeg
# Processing data/rawdata/retouchme-71_clean.jpeg
# Processing data/rawdata/retouchme-59_tattoo.jpeg
# Processing data/rawdata/retouchme-37_tattoo.jpeg
# Processing data/rawdata/retouchme-9_tattoo.jpeg
# Processing data/rawdata/retouchme-57_tattoo.jpeg
# Processing data/rawdata/retouchme-43_tattoo.jpeg
# Processing data/rawdata/retouchme-64_clean.jpeg
# Processing data/rawdata/retouchme-3_clean.jpeg
# Processing data/rawdata/retouchme-46_tattoo.jpeg
# Processing data/rawdata/retouchme-70_clean.jpeg
# Processing data/rawdata/retouchme-63_tattoo.jpeg
# Processing data/rawdata/laser-removal-14_tattoo.jpeg
# Processing data/rawdata/retouchme-49_tattoo.jpeg
# Processing data/rawdata/retouchme-44_tattoo.jpeg
# Processing data/rawdata/retouchme-47_tattoo.jpeg
# Processing data/rawdata/retouchme-11_tattoo.jpeg
# Processing data/rawdata/retouchme-11_clean.jpeg
# Processing data/rawdata/retouchme-25_tattoo.jpeg
# Processing data/rawdata/retouchme-74_clean.jpeg
# Processing data/rawdata/retouchme-77_tattoo.jpeg
# Processing data/rawdata/retouchme-73_tattoo.jpeg
# Processing data/rawdata/retouchme-35_clean.jpeg
# Processing data/rawdata/retouchme-8_clean.jpeg
# Processing data/rawdata/retouchme-40_clean.jpeg
# Processing data/rawdata/laser-removal-5_clean.jpeg
# Processing data/rawdata/retouchme-52_clean.jpeg
# Processing data/rawdata/retouchme-42_clean.jpeg
# Processing data/rawdata/retouchme-4_tattoo.jpeg
# Processing data/rawdata/laser-removal-4_clean.jpeg
# Processing data/rawdata/retouchme-5_tattoo.jpeg
# Processing data/rawdata/retouchme-14_clean.jpeg
# Processing data/rawdata/retouchme-26_clean.jpeg
# Processing data/rawdata/retouchme-20_clean.jpeg
# Processing data/rawdata/retouchme-74_tattoo.jpeg
# Processing data/rawdata/laser-removal-10_clean.jpeg
# Processing data/rawdata/retouchme-1_clean.jpeg
# Processing data/rawdata/laser-removal-9_clean.jpeg
# Processing data/rawdata/retouchme-75_tattoo.jpeg
# Processing data/rawdata/retouchme-53_tattoo.jpeg
# Processing data/rawdata/retouchme-37_clean.jpeg
# Processing data/rawdata/retouchme-3_tattoo.jpeg
# Processing data/rawdata/retouchme-18_clean.jpeg
# Processing data/rawdata/retouchme-16_clean.jpeg
# Processing data/rawdata/retouchme-48_tattoo.jpeg
# Processing data/rawdata/retouchme-34_clean.jpeg
# Processing data/rawdata/laser-removal-9_tattoo.jpeg
# Processing data/rawdata/retouchme-23_clean.jpeg
# Processing data/rawdata/laser-removal-10_tattoo.jpeg
# Processing data/rawdata/retouchme-8_tattoo.jpeg
# Processing data/rawdata/retouchme-63_clean.jpeg
# Processing data/rawdata/retouchme-47_clean.jpeg
# Processing data/rawdata/retouchme-26_tattoo.jpeg
# Processing data/rawdata/retouchme-58_clean.jpeg
# Processing data/rawdata/retouchme-27_tattoo.jpeg
# Processing data/rawdata/retouchme-33_tattoo.jpeg
# Processing data/rawdata/retouchme-46_clean.jpeg
# Processing data/rawdata/retouchme-56_clean.jpeg
# Processing data/rawdata/retouchme-69_tattoo.jpeg
# Processing data/rawdata/laser-removal-8_clean.jpeg
# Processing data/rawdata/retouchme-57_clean.jpeg
# Processing data/rawdata/retouchme-68_tattoo.jpeg
# Processing data/rawdata/laser-removal-2_tattoo.jpeg
# Processing data/rawdata/retouchme-66_tattoo.jpeg
# Processing data/rawdata/retouchme-32_tattoo.jpeg
# Processing data/rawdata/retouchme-72_clean.jpeg
# Processing data/rawdata/retouchme-52_tattoo.jpeg
# Processing data/rawdata/retouchme-35_tattoo.jpeg
# Processing data/rawdata/laser-removal-3_clean.jpeg
# Processing data/rawdata/retouchme-12_tattoo.jpeg
# Processing data/rawdata/retouchme-23_tattoo.jpeg
# /usr/local/lib/python3.8/dist-packages/PIL/TiffImagePlugin.py:858: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 2.
#   warnings.warn(str(msg))
# Processing data/rawdata/retouchme-29_clean.jpeg
# Processing data/rawdata/laser-removal-1_clean.jpeg
# Processing data/rawdata/retouchme-4_clean.jpeg
# Processing data/rawdata/retouchme-72_tattoo.jpeg
# Processing data/rawdata/retouchme-64_tattoo.jpeg
# Processing data/rawdata/retouchme-24_clean.jpeg
# Processing data/rawdata/laser-removal-16_clean.jpeg
# Processing data/rawdata/retouchme-38_clean.jpeg
# Processing data/rawdata/retouchme-30_tattoo.jpeg
# Processing data/rawdata/retouchme-30_clean.jpeg
# Processing data/rawdata/laser-removal-15_tattoo.jpeg
# Processing data/rawdata/retouchme-62_tattoo.jpeg
# Processing data/rawdata/retouchme-60_tattoo.jpeg
# Processing data/rawdata/retouchme-50_tattoo.jpeg
# Processing data/rawdata/laser-removal-12_tattoo.jpeg
# Processing data/rawdata/retouchme-49_clean.jpeg
# Processing data/rawdata/retouchme-58_tattoo.jpeg
# Processing data/rawdata/retouchme-25_clean.jpeg
# Processing data/rawdata/retouchme-66_clean.jpeg
# Processing data/rawdata/retouchme-71_tattoo.jpeg
# Processing data/rawdata/retouchme-24_tattoo.jpeg
# Processing data/rawdata/retouchme-2_clean.jpeg
# Processing data/rawdata/retouchme-20_tattoo.jpeg
# Processing data/rawdata/retouchme-9_clean.jpeg
# Processing data/rawdata/laser-removal-6_clean.jpeg
# Processing data/rawdata/retouchme-65_tattoo.jpeg
# Processing data/rawdata/retouchme-51_tattoo.jpeg
# Processing data/rawdata/retouchme-6_clean.jpeg
# Processing data/rawdata/retouchme-68_clean.jpeg
# Processing data/rawdata/laser-removal-7_tattoo.jpeg
# Processing data/rawdata/retouchme-22_tattoo.jpeg
# Processing data/rawdata/retouchme-50_clean.jpeg
# Processing data/rawdata/retouchme-33_clean.jpeg
# Processing data/rawdata/retouchme-19_clean.jpeg
# Processing data/rawdata/retouchme-67_clean.jpeg
# Processing data/rawdata/retouchme-45_clean.jpeg
# Processing data/rawdata/retouchme-13_tattoo.jpeg
# Processing data/rawdata/retouchme-61_clean.jpeg
# Processing data/rawdata/retouchme-65_clean.jpeg
# Processing data/rawdata/retouchme-42_tattoo.jpeg
# Processing data/rawdata/retouchme-36_clean.jpeg
# Processing data/rawdata/retouchme-14_tattoo.jpeg
# Processing data/rawdata/retouchme-78_clean.jpeg
# Processing data/rawdata/retouchme-73_clean.jpeg
# Processing data/rawdata/retouchme-2_tattoo.jpeg
# Processing data/rawdata/retouchme-21_clean.jpeg
# Processing data/rawdata/laser-removal-12_clean.jpeg
# Processing data/rawdata/retouchme-27_clean.jpeg
# Processing data/rawdata/retouchme-70_tattoo.jpeg
# Processing data/rawdata/retouchme-60_clean.jpeg
# Processing data/rawdata/retouchme-5_clean.jpeg
# Processing data/rawdata/retouchme-29_tattoo.jpeg
# Processing data/rawdata/retouchme-59_clean.jpeg
# Processing data/rawdata/retouchme-36_tattoo.jpeg
# Processing data/rawdata/retouchme-53_clean.jpeg
# Processing data/rawdata/retouchme-10_tattoo.jpeg
# Processing data/rawdata/retouchme-31_clean.jpeg
# Processing data/rawdata/laser-removal-7_clean.jpeg
# Processing data/rawdata/retouchme-39_tattoo.jpeg
# Processing data/rawdata/retouchme-6_tattoo.jpeg
# Processing data/rawdata/laser-removal-6_tattoo.jpeg
# Processing data/rawdata/retouchme-55_clean.jpeg
# Processing data/rawdata/retouchme-41_tattoo.jpeg
# Processing data/rawdata/retouchme-62_clean.jpeg
# Processing data/rawdata/laser-removal-15_clean.jpeg
# Processing data/rawdata/retouchme-17_clean.jpeg
# Processing data/rawdata/retouchme-55_tattoo.jpeg
# Processing data/rawdata/retouchme-17_tattoo.jpeg
# Processing data/rawdata/retouchme-41_clean.jpeg
# Processing data/rawdata/retouchme-21_tattoo.jpeg
# Processing data/rawdata/retouchme-40_tattoo.jpeg
# Processing data/rawdata/retouchme-61_tattoo.jpeg
# Processing data/rawdata/retouchme-43_clean.jpeg
# Processing data/rawdata/retouchme-44_clean.jpeg
# Processing data/rawdata/laser-removal-11_tattoo.jpeg
# Processing data/rawdata/retouchme-69_clean.jpeg
# Processing data/rawdata/retouchme-76_clean.jpeg
# Processing data/rawdata/laser-removal-2_clean.jpeg
# Processing data/rawdata/laser-removal-1_tattoo.jpeg
# Processing data/rawdata/laser-removal-4_tattoo.jpeg
# Processing data/rawdata/retouchme-28_clean.jpeg
# Processing data/rawdata/retouchme-48_clean.jpeg
# Processing data/rawdata/laser-removal-8_tattoo.jpeg
